# %% [markdown]
# Sources:
# https://www.kaggle.com/datasets/rxnach/student-stress-factors-a-comprehensive-analysis/data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

import statsmodels.api as sm

# %%
data = pd.read_csv('StressLevelDataset.csv')

# %% [markdown]
# 1) Anxiety : range from 0 to 21, Measure : GAD-7
# 2) Self-esteem : range 0 to 30, Measure: Rosenberg Self Esteem Scale
# 3) Mental Health History : 0 if no mental health history, 1 if mental health history
# 4) Depression : range 0 to 27, Measure: Patient Health Questionnaire (PHQ-9)
# 5) Other features mostly range from 0 to 5 considering 0,1 to be low, 2,3 to be mid, and 4,5 to be high.

# %% [markdown]
# Psychological Factors => 'anxiety_level', 'self_esteem', 'mental_health_history', 'depression',
#
# Physiological Factors => 'headache', 'blood_pressure', 'sleep_quality', 'breathing_problem
#
# Environmental Factors => 'noise_level', 'living_conditions', 'safety', 'basic_needs',
#
# Academic Factors => 'academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns',
#
# Social Factor => 'social_support', 'peer_pressure', 'extracurricular_activities', 'bullying'

# %%
data.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1100 non-null   int64
#  3   depression                    1100 non-null   int64
#  4   headache                      1100 non-null   int64
#  5   blood_pressure                1100 non-null   int64
#  6   sleep_quality                 1100 non-null   int64
#  7   breathing_problem             1100 non-null   int64
#  8   noise_level                   1100 non-null   int64
#  9   living_conditions             1100 non-null   int64
#  10  safety                        1100 non-null   int64
#  11  basic_needs                   1100 non-null   int64
#  12  academic_performance          1100 non-null   int64
# ...

# %%
data.isna().any()
# Out:
# anxiety_level                   False
# self_esteem                     False
# mental_health_history           False
# depression                      False
# headache                        False
# blood_pressure                  False
# sleep_quality                   False
# breathing_problem               False
# noise_level                     False
# living_conditions               False
# safety                          False
# basic_needs                     False
# academic_performance            False
# study_load                      False
# teacher_student_relationship    False
# future_career_concerns          False
# social_support                  False
# peer_pressure                   False
# extracurricular_activities      False
# bullying                        False
# stress_level                    False
# dtype: bool

# %%
plt.figure(figsize=(15, 10))
data.hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
plt.title('Numerical Features Distribution')
plt.show()

# %%
corr = data.corr()

# %%
# Heatmap of correlations
plt.figure(figsize=(15, 10))
sns.heatmap(corr, cmap='coolwarm', annot=True, linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Linear Regression with one variable
X = sm.add_constant(data['bullying'])
y = data['stress_level']

model1 = sm.OLS(y, X)
results1 = model1.fit()

slope1 = round(results1.params['bullying'], 2)
intercept1 = round(results1.params['const'], 2)

print("Equation : y = {}x + {}".format(slope1, intercept1))
print(results1.summary())
# Out:
# Equation : y = 0.4x + -0.06
#                             OLS Regression Results
# ...
# Dep. Variable:           stress_level   R-squared:                       0.564
# Model:                            OLS   Adj. R-squared:                  0.564
# Method:                 Least Squares   F-statistic:                     1422.
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):          2.82e-200
# Time:                        18:29:44   Log-Likelihood:                -887.41
# No. Observations:                1100   AIC:                             1779.
# Df Residuals:                    1098   BIC:                             1789.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0588      0.032     -1.814      0.070      -0.122       0.005
# ...

# %%
# residuals
fig = plt.figure(figsize= (15,8))
sm.graphics.plot_regress_exog(results1, 'bullying', fig)
plt.show()

# %% [markdown]
# ## Multiple Regression

# %%
# Multiple Regression
ML_X = data[['self_esteem', 'sleep_quality', 'bullying', 'depression', 'future_career_concerns', 'academic_performance', 'peer_pressure']]
ML_y = data['stress_level']

ML_X_withconst = sm.add_constant(ML_X)
ML_model = sm.OLS(ML_y, ML_X_withconst)
ML_results = ML_model.fit()
print(ML_results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           stress_level   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     504.8
# Date:                Mon, 22 Apr 2024   Prob (F-statistic):               0.00
# Time:                        18:29:55   Log-Likelihood:                -550.34
# No. Observations:                1100   AIC:                             1117.
# Df Residuals:                    1092   BIC:                             1157.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                      1.1256      0.097     11.578      0.000       0.935       1.316
# ...

# %% [markdown]
# ## Multiple Regression categorized by factors

# %%
def ols_regression(X, y):
    """
    Perform Ordinary Least Squares (OLS) regression and return the R-squared value and p-values of coefficients.

    Parameters:
    X (DataFrame): Independent variables.
    y (Series): Dependent variable.

    Returns:
    tuple: R-squared value, p-values of coefficients.
    """
    X_with_const = sm.add_constant(X)
    model = sm.OLS(y, X_with_const)
    results = model.fit()
    return round(results.rsquared, 3), [round(p, 3) for p in results.pvalues[1:]]

# %%
factors = {'psychological': ['anxiety_level', 'self_esteem', 'mental_health_history', 'depression'],
          'physiological': ['headache', 'blood_pressure', 'sleep_quality', 'breathing_problem'], 
          'environmental': [ 'noise_level', 'living_conditions', 'safety', 'basic_needs'], 
          'academic': ['academic_performance', 'study_load', 'teacher_student_relationship', 'future_career_concerns'],
          'social': [ 'social_support', 'peer_pressure', 'extracurricular_activities', 'bullying']}

# %%
ML_y = data['stress_level']

for category, factors_list in factors.items():
    X = data[factors_list]
    r_squared, p_values = ols_regression(X, ML_y)
    print(f"R-squared value for {category} factors: {r_squared}")
    print(f"P-values for {category} factors:")
    for feature, p_value in zip(factors_list, p_values):
        #if p_value > 0.005:
        print(f"{feature}: {p_value}")
    print()
# Out:
# R-squared value for psychological factors: 0.706
# P-values for psychological factors:
# anxiety_level: 0.0
# self_esteem: 0.0
# mental_health_history: 0.0
# depression: 0.0
#
# R-squared value for physiological factors: 0.69
# P-values for physiological factors:
# headache: 0.0
# blood_pressure: 0.0
# sleep_quality: 0.0
# breathing_problem: 0.0
#
# R-squared value for environmental factors: 0.684
# P-values for environmental factors:
# noise_level: 0.0
# living_conditions: 0.0
# safety: 0.0
# basic_needs: 0.0
#
# R-squared value for academic factors: 0.696
# P-values for academic factors:
# academic_performance: 0.0
# study_load: 0.0
# teacher_student_relationship: 0.0
# future_career_concerns: 0.0
#
# R-squared value for social factors: 0.697
# P-values for social factors:
# social_support: 0.0
# peer_pressure: 0.0
# extracurricular_activities: 0.0
# bullying: 0.0
